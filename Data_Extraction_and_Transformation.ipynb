# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import mysql.connector as sql
import streamlit as st
import plotly.express as px
import os
import json
from streamlit_option_menu import option_menu
from PIL import Image

# %% [markdown]
# Data Extraction
#
# Cloning Data from Github

# %%
os.environ["GIT_PYTHON_REFRESH"] = "quiet"
import git
from git.repo.base import Repo
Repo.clone_from("https://github.com/PhonePe/pulse.git", "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data")
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# Cell In[9], line 4
#       2 import git
#       3 from git.repo.base import Repo
# ----> 4 Repo.clone_from("https://github.com/PhonePe/pulse.git", "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data")
#
# File c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\git\repo\base.py:1328, in Repo.clone_from(cls, url, to_path, progress, env, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1326 if env is not None:
#    1327     git.update_environment(**env)
# -> 1328 return cls._clone(
#    1329     git,
#    1330     url,
#    1331     to_path,
#    1332     GitCmdObjectDB,
#    1333     progress,
#    1334     multi_options,
#    1335     allow_unsafe_protocols=allow_unsafe_protocols,
#    1336     allow_unsafe_options=allow_unsafe_options,
#    1337     **kwargs,
#    1338 )
#
# File c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\git\repo\base.py:1237, in Repo._clone(cls, git, url, path, odb_default_type, progress, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1234     cmdline = remove_password_if_present(cmdline)
#    1236     log.debug("Cmd(%s)'s unused stdout: %s", cmdline, stdout)
# -> 1237     finalize_process(proc, stderr=stderr)
#    1239 # our git command could have a different working dir than our actual
#    1240 # environment, hence we prepend its working dir if required
#    1241 if not osp.isabs(path):
#
# File c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\git\util.py:453, in finalize_process(proc, **kwargs)
#     451 """Wait for the process (clone, fetch, pull or push) and handle its errors accordingly"""
#     452 # TODO: No close proc-streams??
# --> 453 proc.wait(**kwargs)
#
# File c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\git\cmd.py:600, in Git.AutoInterrupt.wait(self, stderr)
#     598     errstr = read_all_from_possibly_closed_stream(p_stderr)
#     599     log.debug("AutoInterrupt wait stderr: %r" % (errstr,))
# --> 600     raise GitCommandError(remove_password_if_present(self.args), status, errstr)
#     601 return status
#
# GitCommandError: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/PhonePe/pulse.git C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data
#   stderr: 'fatal: destination path 'C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data' already exists and is not an empty directory.
# '

# %% [markdown]
# Data transformation
#
# Dataframe of aggregated transactions

# %%
path1 = "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1)

columns1 = {'State': [], 'Year': [], 'Quarter': [], 'Transaction_type': [], 'Transaction_count': [],
            'Transaction_amount': []}
for state in agg_trans_list:
    cur_state = path1 + state + "/"
    agg_year_list = os.listdir(cur_state)
    
    for year in agg_year_list:
        cur_year = cur_state + year + "/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            A = json.load(data)
            
            for i in A['data']['transactionData']:
                name = i['name']
                count = i['paymentInstruments'][0]['count']
                amount = i['paymentInstruments'][0]['amount']
                columns1['Transaction_type'].append(name)
                columns1['Transaction_count'].append(count)
                columns1['Transaction_amount'].append(amount)
                columns1['State'].append(state)
                columns1['Year'].append(year)
                columns1['Quarter'].append(int(file.strip('.json')))
                
df_agg_trans = pd.DataFrame(columns1)

# %%
df_agg_trans.shape
# Out:
# (4314, 6)

# %% [markdown]
# Dataframe of aggregated user

# %%
path2 = "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data/pulse/data/aggregated/user/country/india/state/"

agg_user_list = os.listdir(path2)

columns2 = {'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': []}
for state in agg_user_list:
    cur_state = path2 + state + "/"
    agg_year_list = os.listdir(cur_state)
    
    for year in agg_year_list:
        cur_year = cur_state + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            B = json.load(data)
            try:
                for i in B["data"]["usersByDevice"]:
                    brand_name = i["brand"]
                    counts = i["count"]
                    percents = i["percentage"]
                    columns2["Brands"].append(brand_name)
                    columns2["Count"].append(counts)
                    columns2["Percentage"].append(percents)
                    columns2["State"].append(state)
                    columns2["Year"].append(year)
                    columns2["Quarter"].append(int(file.strip('.json')))
            except:
                pass
df_agg_user = pd.DataFrame(columns2)

# %%
df_agg_user
# Out:
#                           State  Year  Quarter   Brands    Count  Percentage
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018        1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018        1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018        1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018        1  OnePlus      332    0.049258
# ...                         ...   ...      ...      ...      ...         ...
# 6727                west-bengal  2022        1   Lenovo   330017    0.015056
# 6728                west-bengal  2022        1  Infinix   284678    0.012987
# 6729                west-bengal  2022        1     Asus   280347    0.012790
# 6730                west-bengal  2022        1    Apple   277752    0.012671
# 6731                west-bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %% [markdown]
# Dataframe of map transactions

# %%
path3 = "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data/pulse/data/map/transaction/hover/country/india/state/"

map_trans_list = os.listdir(path3)

columns3 = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': [],
            'Amount': []}

for state in map_trans_list:
    cur_state = path3 + state + "/"
    map_year_list = os.listdir(cur_state)
    
    for year in map_year_list:
        cur_year = cur_state + year + "/"
        map_file_list = os.listdir(cur_year)
        
        for file in map_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            C = json.load(data)
            
            for i in C["data"]["hoverDataList"]:
                district = i["name"]
                count = i["metric"][0]["count"]
                amount = i["metric"][0]["amount"]
                columns3["District"].append(district)
                columns3["Count"].append(count)
                columns3["Amount"].append(amount)
                columns3['State'].append(state)
                columns3['Year'].append(year)
                columns3['Quarter'].append(int(file.strip('.json')))
                
df_map_trans = pd.DataFrame(columns3)

# %%
df_map_trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 17559                west-bengal  2023        4
# 17560                west-bengal  2023        4
# 17561                west-bengal  2023        4
# 17562                west-bengal  2023        4
# 17563                west-bengal  2023        4
#
#                                 District     Count        Amount
# 0      north and middle andaman district       442  9.316631e+05
# 1                 south andaman district      5688  1.256025e+07
# 2                      nicobars district       528  1.139849e+06
# 3      north and middle andaman district       825  1.317863e+06
# 4                 south andaman district      9395  2.394824e+07
# ...                                  ...       ...           ...
# 17559                     nadia district  36242432  6.879568e+10
# 17560                   birbhum district  20708496  3.690499e+10
# 17561           purba medinipur district  40572042  7.981990e+10
# 17562                    maldah district  34654950  6.416729e+10
# 17563                 darjiling district  16807885  2.793986e+10
#
# [17564 rows x 6 columns]

# %% [markdown]
# Dataframe of map user

# %%
path4 = "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data/pulse/data/map/user/hover/country/india/state/"

map_user_list = os.listdir(path4)

columns4 = {"State": [], "Year": [], "Quarter": [], "District": [],
            "RegisteredUser": [], "AppOpens": []}

for state in map_user_list:
    cur_state = path4 + state + "/"
    map_year_list = os.listdir(cur_state)
    
    for year in map_year_list:
        cur_year = cur_state + year + "/"
        map_file_list = os.listdir(cur_year)
        
        for file in map_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            D = json.load(data)
            
            for i in D["data"]["hoverData"].items():
                district = i[0]
                registereduser = i[1]["registeredUsers"]
                appOpens = i[1]['appOpens']
                columns4["District"].append(district)
                columns4["RegisteredUser"].append(registereduser)
                columns4["AppOpens"].append(appOpens)
                columns4['State'].append(state)
                columns4['Year'].append(year)
                columns4['Quarter'].append(int(file.strip('.json')))
                
df_map_user = pd.DataFrame(columns4)

# %%
df_map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 17563                west-bengal  2023        4
# 17564                west-bengal  2023        4
# 17565                west-bengal  2023        4
# 17566                west-bengal  2023        4
# 17567                west-bengal  2023        4
#
#                                 District  RegisteredUser  AppOpens
# 0      north and middle andaman district             632         0
# 1                 south andaman district            5846         0
# 2                      nicobars district             262         0
# 3      north and middle andaman district             911         0
# 4                 south andaman district            8143         0
# ...                                  ...             ...       ...
# 17563                     nadia district         1603527  67224546
# 17564                   birbhum district         1013025  52281841
# 17565           purba medinipur district         1589203  69991821
# 17566                    maldah district         1134600  88292475
# 17567                 darjiling district          660231  39079247
#
# [17568 rows x 6 columns]

# %% [markdown]
# Dataframe of top transactions

# %%
path5 = "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data/pulse/data/top/transaction/country/india/state/"

top_trans_list = os.listdir(path5)
columns5 = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Transaction_count': [],
            'Transaction_amount': []}

for state in top_trans_list:
    cur_state = path5 + state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            E = json.load(data)
            
            for i in E['data']['pincodes']:
                name = i['entityName']
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns5['Pincode'].append(name)
                columns5['Transaction_count'].append(count)
                columns5['Transaction_amount'].append(amount)
                columns5['State'].append(state)
                columns5['Year'].append(year)
                columns5['Quarter'].append(int(file.strip('.json')))
df_top_trans = pd.DataFrame(columns5)

# %%
df_top_trans
# Out:
#                           State  Year  Quarter Pincode  Transaction_count  \
# 0     andaman-&-nicobar-islands  2018        1  744101               1622
# 1     andaman-&-nicobar-islands  2018        1  744103               1223
# 2     andaman-&-nicobar-islands  2018        1  744102                969
# 3     andaman-&-nicobar-islands  2018        1  744105                685
# 4     andaman-&-nicobar-islands  2018        1  744104                340
# ...                         ...   ...      ...     ...                ...
# 8562                west-bengal  2023        4  721301            4133775
# 8563                west-bengal  2023        4  700001            3983241
# 8564                west-bengal  2023        4  732125            3950411
# 8565                west-bengal  2023        4  700039            3742452
# 8566                west-bengal  2023        4  700014            3652710
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...                  ...
# 8562        5.718222e+09
# 8563        8.039689e+09
# 8564        6.557345e+09
# 8565        5.608622e+09
# 8566        6.184795e+09
#
# [8567 rows x 6 columns]

# %% [markdown]
# Dataframe of top users

# %%
path6 = "C:/Users/krish/OneDrive/Desktop/phonepe-pulse/data/pulse/data/top/user/country/india/state/"
top_user_list = os.listdir(path6)
columns6 = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [],
            'RegisteredUsers': []}

for state in top_user_list:
    cur_state = path6 + state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            F = json.load(data)
            
            for i in F['data']['pincodes']:
                name = i['name']
                registeredUsers = i['registeredUsers']
                columns6['Pincode'].append(name)
                columns6['RegisteredUsers'].append(registeredUsers)
                columns6['State'].append(state)
                columns6['Year'].append(year)
                columns6['Quarter'].append(int(file.strip('.json')))
df_top_user = pd.DataFrame(columns6)

# %%
df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1  744103             1608
# 1     andaman-&-nicobar-islands  2018        1  744101             1108
# 2     andaman-&-nicobar-islands  2018        1  744105             1075
# 3     andaman-&-nicobar-islands  2018        1  744102             1006
# 4     andaman-&-nicobar-islands  2018        1  744104              272
# ...                         ...   ...      ...     ...              ...
# 8563                west-bengal  2023        4  700015           126663
# 8564                west-bengal  2023        4  742304           123320
# 8565                west-bengal  2023        4  721101           123088
# 8566                west-bengal  2023        4  700150           119283
# 8567                west-bengal  2023        4  700091           118578
#
# [8568 rows x 5 columns]

# %% [markdown]
# Converting dataframe to csv files

# %%
df_agg_trans.to_csv('agg_trans.csv',index=False)
df_agg_user.to_csv('agg_user.csv',index=False)
df_map_trans.to_csv('map_trans.csv',index=False)
df_map_user.to_csv('map_user.csv',index=False)
df_top_trans.to_csv('top_trans.csv',index=False)
df_top_user.to_csv('top_user.csv',index=False)

# %%
pwd
# Out:
# 'C:\\Users\\krish\\OneDrive\\Desktop\\phonepe-pulse'

# %% [markdown]
# Creating connection with mysql

# %%
mydb = sql.connect(host="localhost",
                   user="root",
                   password="mysql@50345034",
                   database= "pulse_data",
                   auth_plugin='mysql_native_password'
                  )
mycursor = mydb.cursor(buffered=True)

# %% [markdown]
# Create agg trans table

# %%
mycursor.execute("create table agg_trans (State varchar(100), Year int, Quarter int, Transaction_type varchar(100), Transaction_count int, Transaction_amount double)")

for i,row in df_agg_trans.iterrows():
    #here %S means string values 
    sql = "INSERT INTO agg_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()

# %% [markdown]
# Create agg user table

# %%
mycursor.execute("create table agg_user (State varchar(100), Year int, Quarter int, Brands varchar(100), Count int, Percentage double)")

for i,row in df_agg_user.iterrows():
    sql = "INSERT INTO agg_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %% [markdown]
# Create map trans table

# %%
mycursor.execute("create table map_trans (State varchar(100), Year int, Quarter int, District varchar(100), Count int, Amount double)")

for i,row in df_map_trans.iterrows():
    sql = "INSERT INTO map_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %% [markdown]
# Create map user table

# %%
mycursor.execute("create table map_user (State varchar(100), Year int, Quarter int, District varchar(100), Registered_user int, App_opens int)")

for i,row in df_map_user.iterrows():
    sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %% [markdown]
# Create top trans table

# %%
mycursor.execute("create table top_trans (State varchar(100), Year int, Quarter int, Pincode int, Transaction_count int, Transaction_amount double)")

for i,row in df_top_trans.iterrows():
    sql = "INSERT INTO top_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %% [markdown]
# Create top user table

# %%
mycursor.execute("create table top_user (State varchar(100), Year int, Quarter int, Pincode int, Registered_users int)")

for i,row in df_top_user.iterrows():
    sql = "INSERT INTO top_user VALUES (%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %% [markdown]
# List of tables

# %%
mycursor.execute("show tables")
mycursor.fetchall()
# Out:
# [('agg_trans',),
#  ('agg_user',),
#  ('map_trans',),
#  ('map_user',),
#  ('top_trans',),
#  ('top_user',)]

# %%
pwd
# Out:
# 'c:\\Users\\krish\\OneDrive\\Desktop\\phonepe-pulse'

# %%
pip install mysql.connector.python
# Out:
# Collecting mysql.connector.pythonNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for mysql.connector.python from https://files.pythonhosted.org/packages/d9/91/007a0d60fee8db4f7385075dc50bf62d2d359b417b374ec06b06ce6c2d64/mysql_connector_python-8.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading mysql_connector_python-8.3.0-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Downloading mysql_connector_python-8.3.0-cp311-cp311-win_amd64.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB 140.3 kB/s eta 0:01:50
#    ---------------------------------------- 0.1/15.4 MB 182.2 kB/s eta 0:01:25
#    ---------------------------------------- 0.1/15.4 MB 312.2 kB/s eta 0:00:50
#    ---------------------------------------- 0.2/15.4 MB 409.6 kB/s eta 0:00:38
#     --------------------------------------- 0.3/15.4 MB 655.2 kB/s eta 0:00:24
#     --------------------------------------- 0.3/15.4 MB 655.2 kB/s eta 0:00:24
#     --------------------------------------- 0.4/15.4 MB 676.0 kB/s eta 0:00:23
#    - -------------------------------------- 0.4/15.4 MB 809.9 kB/s eta 0:00:19
#    - -------------------------------------- 0.5/15.4 MB 723.0 kB/s eta 0:00:21
#    - -------------------------------------- 0.6/15.4 MB 912.0 kB/s eta 0:00:17
#    - -------------------------------------- 0.6/15.4 MB 912.0 kB/s eta 0:00:17
#    - -------------------------------------- 0.8/15.4 MB 996.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/15.4 MB 1.1 MB/s eta 0:00:14
#    -- ------------------------------------- 0.9/15.4 MB 1.1 MB/s eta 0:00:14
#    -- ------------------------------------- 0.9/15.4 MB 1.1 MB/s eta 0:00:14
#    -- ------------------------------------- 1.0/15.4 MB 1.1 MB/s eta 0:00:14
#    -- ------------------------------------- 1.1/15.4 MB 1.1 MB/s eta 0:00:14
#    --- ------------------------------------ 1.2/15.4 MB 1.1 MB/s eta 0:00:13
#    --- ------------------------------------ 1.2/15.4 MB 1.1 MB/s eta 0:00:13
#    --- ------------------------------------ 1.3/15.4 MB 1.1 MB/s eta 0:00:13
#    --- ------------------------------------ 1.4/15.4 MB 1.2 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.6/15.4 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/15.4 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/15.4 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.8/15.4 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.8/15.4 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.8/15.4 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.8/15.4 MB 1.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.9/15.4 MB 1.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.0/15.4 MB 1.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.1/15.4 MB 1.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.3/15.4 MB 1.4 MB/s eta 0:00:10
#    ------ --------------------------------- 2.5/15.4 MB 1.4 MB/s eta 0:00:10
#    ------ --------------------------------- 2.7/15.4 MB 1.5 MB/s eta 0:00:09
#    ------- -------------------------------- 2.9/15.4 MB 1.6 MB/s eta 0:00:08
#    -------- ------------------------------- 3.1/15.4 MB 1.7 MB/s eta 0:00:08
#    -------- ------------------------------- 3.4/15.4 MB 1.7 MB/s eta 0:00:07
#    --------- ------------------------------ 3.6/15.4 MB 1.8 MB/s eta 0:00:07
#    --------- ------------------------------ 3.8/15.4 MB 1.9 MB/s eta 0:00:07
#    ---------- ----------------------------- 4.1/15.4 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.3/15.4 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.5/15.4 MB 2.1 MB/s eta 0:00:06
#    ------------ --------------------------- 4.7/15.4 MB 2.1 MB/s eta 0:00:06
#    ------------ --------------------------- 4.9/15.4 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.2/15.4 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.4/15.4 MB 2.3 MB/s eta 0:00:05
#    -------------- ------------------------- 5.6/15.4 MB 2.3 MB/s eta 0:00:05
#    --------------- ------------------------ 5.8/15.4 MB 2.4 MB/s eta 0:00:05
#    --------------- ------------------------ 5.9/15.4 MB 2.4 MB/s eta 0:00:05
#    --------------- ------------------------ 6.1/15.4 MB 2.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.4 MB 2.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.4 MB 2.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.4 MB 2.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.5/15.4 MB 2.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.8/15.4 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 7.0/15.4 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 7.2/15.4 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 7.5/15.4 MB 2.6 MB/s eta 0:00:04
#    -------------------- ------------------- 7.7/15.4 MB 2.6 MB/s eta 0:00:03
#    -------------------- ------------------- 8.0/15.4 MB 2.7 MB/s eta 0:00:03
#    --------------------- ------------------ 8.2/15.4 MB 2.7 MB/s eta 0:00:03
#    --------------------- ------------------ 8.5/15.4 MB 2.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.4 MB 2.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.9/15.4 MB 2.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.1/15.4 MB 2.8 MB/s eta 0:00:03
#    ------------------------ --------------- 9.3/15.4 MB 2.8 MB/s eta 0:00:03
#    ------------------------ --------------- 9.5/15.4 MB 2.9 MB/s eta 0:00:03
#    ------------------------- -------------- 9.7/15.4 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 10.0/15.4 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 10.1/15.4 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 10.2/15.4 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 10.3/15.4 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 10.4/15.4 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 10.6/15.4 MB 3.3 MB/s eta 0:00:02
#    --------------------------- ------------ 10.7/15.4 MB 3.3 MB/s eta 0:00:02
#    --------------------------- ------------ 10.8/15.4 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.9/15.4 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.2/15.4 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.2/15.4 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.2/15.4 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.2/15.4 MB 3.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.4/15.4 MB 3.4 MB/s eta 0:00:02
#    ------------------------------ --------- 11.8/15.4 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.4 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 12.3/15.4 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.4 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 12.9/15.4 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.4 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.4 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.4 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.8/15.4 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.4 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.3/15.4 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.6/15.4 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.4 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.4 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.4 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.4 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.4 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: mysql.connector.python
# Successfully installed mysql.connector.python-8.3.0

# %%
pip install streamlit_option_menu
# Out:
# Collecting streamlit_option_menu
#   Obtaining dependency information for streamlit_option_menu from https://files.pythonhosted.org/packages/d9/e5/a04e14be8b5faf9c20d330f84490b4184d2bec558719c1def1824cc4862d/streamlit_option_menu-0.3.12-py3-none-any.whl.metadata
#   Downloading streamlit_option_menu-0.3.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: streamlit>=0.63 in d:\anaconda3\lib\site-packages (from streamlit_option_menu) (1.29.0)
# Requirement already satisfied: altair<6,>=4.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.25.1)
# Requirement already satisfied: pyarrow>=6.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.7.1)
# Requirement already satisfied: tzlocal<6,>=1.1 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in d:\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.1.6)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit_option_menu) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit_option_menu) (4.17.3)
# Requirement already satisfied: toolz in d:\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit_option_menu) (0.12.0)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit>=0.63->streamlit_option_menu) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit_option_menu) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit>=0.63->streamlit_option_menu) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit_option_menu) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit_option_menu) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit>=0.63->streamlit_option_menu) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit_option_menu) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit_option_menu) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit_option_menu) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit_option_menu) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit_option_menu) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit_option_menu) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit_option_menu) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->streamlit_option_menu) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit_option_menu) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit_option_menu) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.63->streamlit_option_menu) (0.1.0)
# Downloading streamlit_option_menu-0.3.12-py3-none-any.whl (822 kB)
#    ---------------------------------------- 0.0/822.1 kB ? eta -:--:--
#    - -------------------------------------- 30.7/822.1 kB ? eta -:--:--
#    --- ----------------------------------- 81.9/822.1 kB 907.3 kB/s eta 0:00:01
#    ---- ----------------------------------- 92.2/822.1 kB 1.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 92.2/822.1 kB 1.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 225.3/822.1 kB 1.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 225.3/822.1 kB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 368.6/822.1 kB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 440.3/822.1 kB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 604.2/822.1 kB 1.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 614.4/822.1 kB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 747.5/822.1 kB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 778.2/822.1 kB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 778.2/822.1 kB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 778.2/822.1 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  819.2/822.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 822.1/822.1 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: streamlit_option_menu
# Successfully installed streamlit_option_menu-0.3.12
# Note: you may need to restart the kernel to use updated packages.
